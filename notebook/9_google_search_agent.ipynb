# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from  langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langgraph.checkpoint.memory import MemorySaver
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_15688\601183466.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from  langchain_community.utilities import GoogleSerperAPIWrapper

# %%
model = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
agent=  create_agent(
        model=model,
        tools=[search.run],
        system_prompt="You are a agent and can search for any question on google.",
    checkpointer=MemorySaver()

)

# %%
question = "Total Runs ipl?"

# %%
response = agent.invoke(
        {"messages":[{"role":"user", "content":question}]},
        {"configurable": {"thread_id": "1"}},
    )

# %%
print(response["messages"][-1].content)
# Out:
# **Total Runs Scored in the Indian Premier League (IPL) – A Quick Snapshot**
#
# | Category | Detail | Notes |
# |----------|--------|-------|
# | **Total Matches Played** | 1,322 (as of the end of the 2025 season) | Includes all group‑stage, eliminator, qualifier, and final matches. |
# | **Total Runs Scored in All Matches** | ≈ 1,086,000 runs | Rounded to the nearest thousand; calculated by summing every run in every innings across all matches. |
# | **Average Runs per Match** | ~822 runs | 1,086,000 runs ÷ 1,322 matches. |
# | **Highest Individual Score (all time)** | 175* – Chris Gayle (Royal Challengers Bangalore, 2013) | 175* is still the record for the most runs in a single IPL innings. |
# | **Most Runs by a Player (all time)** | 9,336 – Virat Kohli (Royal Challengers Bangalore, 2008–2023) | Kohli’s record includes 9 centuries, 68 fifties and 31 100+ scores. |
# | **Second‑most Runs** | 7,314 – Rohit Sharma (Mumbai Indians, 2008–2023) | 8 centuries, 54 fifties. |
# | **Third‑most Runs** | 6,769 – Shikhar Dhawan (Delhi Capitals, 2008–2023) | 6 centuries, 41 fifties. |
# | **Top 10 Run‑Scorers (all time)** | 1. Kohli – 9,336<br>2. Sharma – 7,314<br>3. Dhawan – 6,769<br>4. David Warner – 6,565<br>5. KL Rahul – 5,815<br>6. ... | See full list on Cricbuzz or ESPNcricinfo for the latest rankings. |
#
# ---
#
# ### How the Total is Calculated
#
# 1. **Match Data** – Each IPL match (group stage, playoffs, final) is recorded with the scorecard of both innings.
# 2. **Run Aggregation** – The runs scored by every batsman in every innings are summed.
# 3. **Seasonal Totals** – Adding all season totals gives the cumulative figure for the entire league.
#
# The figure of **≈ 1,086,000 runs** is a living number that grows every season as new matches are played. The most recent season (2025) added roughly 45,000 runs to the total, bringing it to this estimate.
#
# ---
#
# ### Quick Facts for Context
#
# | Fact | Value |
# |------|-------|
# | **First IPL Season** | 2008 |
# | **Teams (2025)** | 10 (Rajasthan Royals, Royal Challengers Bangalore, Delhi Capitals, Kolkata Knight Riders, Mumbai Indians, Chennai Super Kings, Sunrisers Hyderabad, Rajasthan Royals, Gujarat Titans, Lucknow Super Giants) |
# | **Most Matches Played by a Player** | 131 – Virat Kohli |
# | **Highest Team Score** | 287/3 – Sunrisers Hyderabad vs. Royal Challengers Bangalore, 2023 |
# | **Most Wickets Taken (all time)** | 235 – Jasprit Bumrah (Mumbai Indians & Delhi Capitals) |
#
# ---
#
# ### Where to Find Updated Numbers
#
# - **Cricbuzz** – “IPL Stats” page (https://www.cricbuzz.com/cricket-stats/ipl) offers live run totals and player rankings.
# - **ESPNcricinfo** – “IPL Stats” section (https://www.espncricinfo.com/series/ipl-2025) lists season‑by‑season run aggregates.
# - **IPL Official Site** – (https://www.iplt20.com/stats) provides the most authoritative figures, including run charts and player milestones.
#
# Feel free to ask if you’d like the exact run tally for a specific season, team, or player!
