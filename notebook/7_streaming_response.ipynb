# %%
from dotenv import load_dotenv
load_dotenv
# Out:
# <function dotenv.main.load_dotenv(dotenv_path: Union[str, ForwardRef('os.PathLike[str]'), NoneType] = None, stream: Optional[IO[str]] = None, verbose: bool = False, override: bool = False, interpolate: bool = True, encoding: Optional[str] = 'utf-8') -> bool>

# %%
from langchain_groq import ChatGroq
llm= ChatGroq(streaming=True,  model='openai/gpt-oss-120b')

# %%
question = "show me something "
res= llm.stream(question)

for chunk in res:
    print(chunk.content, end='')
# Out:
# Here’s a little something for you—feel free to let me know if you had something else in mind!
#
# ---
#
# ### 🎨 ASCII Art
#
# ```
#       /\_/\
#      ( o.o )
#       > ^ <
# ```
#
# A cute cat in just a few characters.
#
# ---
#
# ### ✨ Short Poem
#
# *In the quiet of the night,
# Stars whisper stories bright.
# Dreams take wing on silver streams,
# Guiding hearts to secret gleams.*
#
# ---
#
# ### 📚 Random Fun Fact
#
# Did you know? **Octopuses have three hearts**—two pump blood to the gills, while the third pumps it to the rest of the body. When an octopus swims, the heart that delivers blood to the body actually stops beating, which is why they prefer crawling over swimming—it’s less tiring!
#
# ---
#
# If you were looking for something specific (like a meme, a code snippet, a deeper dive into a topic, etc.), just let me know and I’ll gladly pull it up for you!
